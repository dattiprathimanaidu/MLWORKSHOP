# %%
### support vector machine:
## it is supervised ML algorithm
## it is used for both classification and regression problems
## it provides maximum distance(or) boundaries between classes using hyperplane
## boundary line is also known as hyperplane
## it use the another hyperplanes for classifing data using support vectors.

# %%
import numpy as n
import pandas as p

# %%
# read .csv files into dataframe
df=p.read_csv("mushrooms.csv")
df.sample(5)
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 3507     e         x           f         g       t    n               f
# 1870     e         x           s         n       f    n               f
# 5391     p         f           s         w       t    f               f
# 1123     e         x           f         n       t    n               f
# 6481     p         f           y         e       f    y               f
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 3507            c         b          n  ...                        s
# 1870            w         b          n  ...                        f
# 5391            c         b          p  ...                        f
# 1123            c         b          p  ...                        s
# 6481            c         n          b  ...                        k
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder as le
l=le()
df["class"]=l.fit_transform(df["class"])
df.head()
# Out:
#    class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0      1         x           s         n       t    p               f
# 1      0         x           s         y       t    a               f
# 2      0         b           s         w       t    l               f
# 3      1         x           y         w       t    p               f
# 4      0         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
for col in df.columns:
#print(col)
    
    df[col]=l.fit_transform(df[col])
    df.head()

# %%
# cake input and output
x=df.drop("class",axis=1)
y=df["class"]

# %%
from sklearn.model_selection import train_test_split as tt
x_train,x_test,y_train,y_test=tt(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.svm import SVC as sv
model=sv()
model.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# C:\Users\APSSDC\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.016181229773462782

# %%
# predict the test data
ypre=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score as a
a(y_test,ypre)*100
# Out:
# 0.7518796992481203

# %%
from sklearn.metrics import classification_report as c
c(y_test,ypre)*100
print(c(y_test,ypre))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1257
#            1       1.00      1.00      1.00      1181
#
#    micro avg       1.00      1.00      1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
from sklearn.metrics import confusion_matrix as cm
cm(y_test,ypre)
# Out:
# array([[1257,    0],
#        [   0, 1181]], dtype=int64)

# %%
(1257+1181)/(1257+1181)
# Out:
# 1.0

# %%
1257/(1257)
# Out:
# 1.0

# %%
from sklearn.datasets import load_diabetes as ld

# %%
m=ld()
m.keys()
df=p.DataFrame(m.data,columns=m.feature_names)
df["Target"]=m.target
df.sample(7)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 201 -0.034575  0.050680 -0.055785 -0.015999 -0.009825 -0.007890  0.037595
# 116  0.048974  0.050680  0.058463  0.070073  0.013567  0.020607 -0.021311
# 422 -0.078165  0.050680  0.077863  0.052858  0.078236  0.064447  0.026550
# 217  0.074401 -0.044642  0.031517  0.101058  0.046589  0.036890  0.015505
# 407  0.027178 -0.044642  0.092953 -0.052723  0.008063  0.039709 -0.028674
# 30  -0.060003 -0.044642  0.044451 -0.019442 -0.009825 -0.007577  0.022869
# 362  0.019913  0.050680  0.104809  0.070073 -0.035968 -0.026679 -0.024993
#
#            s4        s5        s6  Target
# 201 -0.039493 -0.052959  0.027917    39.0
# 116  0.034309  0.022004  0.027917   275.0
# 422 -0.002592  0.040672 -0.009362   233.0
# 217 -0.002592  0.033657  0.044485   296.0
# 407  0.021024 -0.048362  0.019633   140.0
# 30  -0.039493 -0.027129 -0.009362   129.0
# 362 -0.002592  0.003712  0.040343   321.0

# %%
x=df.drop("Target",axis=1)
y=df["Target"]

# %%
from sklearn.preprocessing import LabelEncoder as le
j=le()
df["Target"]=j.fit_transform(df["Target"])
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Target
# 0 -0.002592  0.019908 -0.017646     101
# 1 -0.039493 -0.068330 -0.092204      35
# 2 -0.002592  0.002864 -0.025930      92
# 3  0.034309  0.022692 -0.009362     145
# 4 -0.002592 -0.031991 -0.046641      86

# %%
from sklearn.model_selection import train_test_split as tt
x_train,x_test,y_train,y_test=tt(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.svm import SVR as sr
model2=sr()
model2.fit(x_train,y_train)
model2.score(x_train,y_train)*100
# Out:
# C:\Users\APSSDC\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# -1.8689861000186658
